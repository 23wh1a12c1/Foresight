# %%
# !pip install tensorflow

# %%
import tensorflow as tf
#Create a Tensor
tensor_a=tf.constant([[1,2],[3,4]])
print(tensor_a)
# Out:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#Load the MNIST dataset
#from keras.datasets import mnist
(x_train, y_train), (x_test, y_test)= keras.datasets.mnist.load_data()

x_train, x_test=x_train/255.0, x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
#Define a model architecture
model=keras.Sequential([
    layers.Flatten(input_shape=(28,28)),  #Flatten 28x28 images into 1D array
    layers.Dense(128, activation='relu'), #Hidden layer with 128 neurons
    layers.Dense(10, activation='softmax') #Output layer with 10 classes

])

# %%
#Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Train the model
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8794 - loss: 0.4231 - val_accuracy: 0.9575 - val_loss: 0.1423
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9668 - loss: 0.1152 - val_accuracy: 0.9706 - val_loss: 0.0983
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9775 - loss: 0.0746 - val_accuracy: 0.9725 - val_loss: 0.0950
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9831 - loss: 0.0560 - val_accuracy: 0.9754 - val_loss: 0.0808
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9870 - loss: 0.0442 - val_accuracy: 0.9769 - val_loss: 0.0795

# %%
#Evaluate the model
test_loss, test_acc=model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9738 - loss: 0.0912
# Test accuracy: 0.9768999814987183
